# %%
import pandas as pd

# %%
bios = pd.read_csv('data/raw/character_bios.csv')

# %%
# Cleaning

# %%
bios['Race'] = bios.Race
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f743f28a29df> in <module>
# ----> 1 bios['Race'] = str.lower(bios.Race)
#
# TypeError: descriptor 'lower' requires a 'str' object but received a 'Series'

# %%
bios.groupby('Race')[].nunique().sort_values('char', ascending=False)
# Out:
#                                                     char  Name  Race  Age  \
# Race
# Human                                                204   194     1   73
# human                                                 16    10     1    8
# Dwarf                                                 15    15     1    5
# Troll                                                 11    11     1    1
# Vampire                                               10    10     1    7
# {{{race}}}                                             9     2     1    1
# Werewolf                                               6     6     1    0
# Anthropomorphic personification                        6     6     1    1
# God                                                    4     3     1    1
# Dog                                                    2     2     1    0
# Gargoyle                                               2     2     1    0
# Elf                                                    2     2     1    0
# ...
